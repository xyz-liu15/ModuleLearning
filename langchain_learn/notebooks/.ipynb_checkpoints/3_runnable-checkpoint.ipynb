# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
import os

# %%
from rich.traceback import install

install()
# Out:
# <bound method InteractiveShell.excepthook of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x79c385bca210>>

# %%
llm = ChatOpenAI(
    model = "glm-4.5",
    base_url = os.getenv("DMX_API_KEY"),
    api_key = os.getenv("DMX_BASE_URL")
)

print(os.getenv("DMX_API_KEY"))
print(os.getenv("DMX_BASE_URL"))
# Out:
# sk-agRxgVGno6JjX28xQ6o7b4rUrXfznGkD7BSiqpCDpmbwaTWV
# https://www.dmxapi.cn/v1

# %%
prompt = PromptTemplate.from_template("10乘以{num}等于多少？")

# %%
chain = prompt | llm | StrOutputParser()

# %%
# 在调用chain时，invoke只能接受dict类型的数据。
chain.invoke({"num" : 10})
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/ShiWu/.cache/uv/archive-v0/I1WBQIgRLR6B30Ff455B3/lib/python3.12/site-packages/httpx/_trans │
# │ ports/default.py:101 in map_httpcore_exceptions                                                  │
# │                                                                                                  │
# │    98 │   if len(HTTPCORE_EXC_MAP) == 0:                                                         │
# │    99 │   │   HTTPCORE_EXC_MAP = _load_httpcore_exceptions()                                     │
# │   100 │   try:                                                                                   │
# │ ❱ 101 │   │   yield                                                                              │
# │   102 │   except Exception as exc:                                                               │
# │   103 │   │   mapped_exc = None                                                                  │
# │   104                                                                                            │
# │                                                                                                  │
# │ /home/ShiWu/.cache/uv/archive-v0/I1WBQIgRLR6B30Ff455B3/lib/python3.12/site-packages/httpx/_trans │
# │ ports/default.py:250 in handle_request                                                           │
# │                                                                                                  │
# │   247 │   │   │   extensions=request.extensions,                                                 │
# │   248 │   │   )                                                                                  │
# │   249 │   │   with map_httpcore_exceptions():                                                    │
# │ ❱ 250 │   │   │   resp = self._pool.handle_request(req)                                          │
# │   251 │   │                                                                                      │
# │   252 │   │   assert isinstance(resp.stream, typing.Iterable)                                    │
# │   253                                                                                            │
# │                                                                                                  │
# │ /home/ShiWu/.cache/uv/archive-v0/I1WBQIgRLR6B30Ff455B3/lib/python3.12/site-packages/httpcore/_sy │
# │ nc/connection_pool.py:207 in handle_request                                                      │
# │                                                                                                  │
# │   204 │   │   """                                                                                │
# │   205 │   │   scheme = request.url.scheme.decode()                                               │
# │   206 │   │   if scheme == "":                                                                   │
# │ ❱ 207 │   │   │   raise UnsupportedProtocol(                                                     │
# │   208 │   │   │   │   "Request URL is missing an 'http://' or 'https://' protocol."              │
# │   209 │   │   │   )                                                                              │
# │   210 │   │   if scheme not in ("http", "https", "ws", "wss"):                                   │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# UnsupportedProtocol: Request URL is missing an 'http://' or 'https://' protocol.
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/ShiWu/MyPython/ModuleLearning/.venv/lib/python3.12/site-packages/openai/_base_client.py:97 │
# │ 9 in request                                                                                     │
# │                                                                                                  │
# │    976 │   │   │                                                                                 │
# │    977 │   │   │   response = None                                                               │
# │    978 │   │   │   try:                                                                          │
# │ ❱  979 │   │   │   │   response = self._client.send(                                             │
# │    980 │   │   │   │   │   request,                                                              │
# │    981 │   │   │   │   │   stream=stream or self._should_stream_response_body(request=request),  │
# │    982 │   │   │   │   │   **kwargs,                                                             │
# │                                                                                                  │
# │ /home/ShiWu/.cache/uv/archive-v0/I1WBQIgRLR6B30Ff455B3/lib/python3.12/site-packages/httpx/_clien │
# │ t.py:914 in send                                                                                 │
# │                                                                                                  │
# │    911 │   │                                                                                     │
# │    912 │   │   auth = self._build_request_auth(request, auth)                                    │
# │    913 │   │                                                                                     │
# │ ❱  914 │   │   response = self._send_handling_auth(                                              │
# │    915 │   │   │   request,                                                                      │
# │    916 │   │   │   auth=auth,                                                                    │
# │    917 │   │   │   follow_redirects=follow_redirects,                                            │
# │                                                                                                  │
# │ /home/ShiWu/.cache/uv/archive-v0/I1WBQIgRLR6B30Ff455B3/lib/python3.12/site-packages/httpx/_clien │
# │ t.py:942 in _send_handling_auth                                                                  │
# │                                                                                                  │
# │    939 │   │   │   request = next(auth_flow)                                                     │
# │    940 │   │   │                                                                                 │
# │    941 │   │   │   while True:                                                                   │
# │ ❱  942 │   │   │   │   response = self._send_handling_redirects(                                 │
# │    943 │   │   │   │   │   request,                                                              │
# │    944 │   │   │   │   │   follow_redirects=follow_redirects,                                    │
# │    945 │   │   │   │   │   history=history,                                                      │
# │                                                                                                  │
# │ /home/ShiWu/.cache/uv/archive-v0/I1WBQIgRLR6B30Ff455B3/lib/python3.12/site-packages/httpx/_clien │
# │ t.py:979 in _send_handling_redirects                                                             │
# │                                                                                                  │
# │    976 │   │   │   for hook in self._event_hooks["request"]:                                     │
# │    977 │   │   │   │   hook(request)                                                             │
# │    978 │   │   │                                                                                 │
# │ ❱  979 │   │   │   response = self._send_single_request(request)                                 │
# │    980 │   │   │   try:                                                                          │
# │    981 │   │   │   │   for hook in self._event_hooks["response"]:                                │
# │    982 │   │   │   │   │   hook(response)                                                        │
# │                                                                                                  │
# │ /home/ShiWu/.cache/uv/archive-v0/I1WBQIgRLR6B30Ff455B3/lib/python3.12/site-packages/httpx/_clien │
# │ t.py:1014 in _send_single_request                                                                │
# │                                                                                                  │
# │   1011 │   │   │   )                                                                             │
# │   1012 │   │                                                                                     │
# │   1013 │   │   with request_context(request=request):                                            │
# │ ❱ 1014 │   │   │   response = transport.handle_request(request)                                  │
# │   1015 │   │                                                                                     │
# │   1016 │   │   assert isinstance(response.stream, SyncByteStream)                                │
# │   1017                                                                                           │
# │                                                                                                  │
# │ /home/ShiWu/.cache/uv/archive-v0/I1WBQIgRLR6B30Ff455B3/lib/python3.12/site-packages/httpx/_trans │
# │ ports/default.py:249 in handle_request                                                           │
# │                                                                                                  │
# │   246 │   │   │   content=request.stream,                                                        │
# │   247 │   │   │   extensions=request.extensions,                                                 │
# │   248 │   │   )                                                                                  │
# │ ❱ 249 │   │   with map_httpcore_exceptions():                                                    │
# │   250 │   │   │   resp = self._pool.handle_request(req)                                          │
# │   251 │   │                                                                                      │
# │   252 │   │   assert isinstance(resp.stream, typing.Iterable)                                    │
# │                                                                                                  │
# │ /home/ShiWu/.local/share/uv/python/cpython-3.12.7-linux-x86_64-gnu/lib/python3.12/contextlib.py: │
# │ 158 in __exit__                                                                                  │
# │                                                                                                  │
# │   155 │   │   │   │   # tell if we get the same exception back                                   │
# │   156 │   │   │   │   value = typ()                                                              │
# │   157 │   │   │   try:                                                                           │
# │ ❱ 158 │   │   │   │   self.gen.throw(value)                                                      │
# │   159 │   │   │   except StopIteration as exc:                                                   │
# │   160 │   │   │   │   # Suppress StopIteration *unless* it's the same exception that             │
# │   161 │   │   │   │   # was passed to throw().  This prevents a StopIteration                    │
# │                                                                                                  │
# │ /home/ShiWu/.cache/uv/archive-v0/I1WBQIgRLR6B30Ff455B3/lib/python3.12/site-packages/httpx/_trans │
# │ ports/default.py:118 in map_httpcore_exceptions                                                  │
# │                                                                                                  │
# │   115 │   │   │   raise                                                                          │
# │   116 │   │                                                                                      │
# │   117 │   │   message = str(exc)                                                                 │
# │ ❱ 118 │   │   raise mapped_exc(message) from exc                                                 │
# │   119                                                                                            │
# │   120                                                                                            │
# │   121 class ResponseStream(SyncByteStream):                                                      │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# UnsupportedProtocol: Request URL is missing an 'http://' or 'https://' protocol.
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:2                                                                                    │
# │                                                                                                  │
# │   1 # 在调用chain时，invoke只能接受dict类型的数据。                                              │
# │ ❱ 2 chain.invoke({"num" : 10})                                                                   │
# │   3                                                                                              │
# │                                                                                                  │
# │ /home/ShiWu/MyPython/ModuleLearning/.venv/lib/python3.12/site-packages/langchain_core/runnables/ │
# │ base.py:3046 in invoke                                                                           │
# │                                                                                                  │
# │   3043 │   │   │   │   │   if i == 0:                                                            │
# │   3044 │   │   │   │   │   │   input_ = context.run(step.invoke, input_, config, **kwargs)       │
# │   3045 │   │   │   │   │   else:                                                                 │
# │ ❱ 3046 │   │   │   │   │   │   input_ = context.run(step.invoke, input_, config)                 │
# │   3047 │   │   # finish the root run                                                             │
# │   3048 │   │   except BaseException as e:                                                        │
# │   3049 │   │   │   run_manager.on_chain_error(e)                                                 │
# │                                                                                                  │
# │ /home/ShiWu/MyPython/ModuleLearning/.venv/lib/python3.12/site-packages/langchain_core/language_m │
# │ odels/chat_models.py:395 in invoke                                                               │
# │                                                                                                  │
# │    392 │   │   config = ensure_config(config)                                                    │
# │    393 │   │   return cast(                                                                      │
# │    394 │   │   │   "ChatGeneration",                                                             │
# │ ❱  395 │   │   │   self.generate_prompt(                                                         │
# │    396 │   │   │   │   [self._convert_input(input)],                                             │
# │    397 │   │   │   │   stop=stop,                                                                │
# │    398 │   │   │   │   callbacks=config.get("callbacks"),                                        │
# │                                                                                                  │
# │ /home/ShiWu/MyPython/ModuleLearning/.venv/lib/python3.12/site-packages/langchain_core/language_m │
# │ odels/chat_models.py:980 in generate_prompt                                                      │
# │                                                                                                  │
# │    977 │   │   **kwargs: Any,                                                                    │
# │    978 │   ) -> LLMResult:                                                                       │
# │    979 │   │   prompt_messages = [p.to_messages() for p in prompts]                              │
# │ ❱  980 │   │   return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)   │
# │    981 │                                                                                         │
# │    982 │   @override                                                                             │
# │    983 │   async def agenerate_prompt(                                                           │
# │                                                                                                  │
# │ /home/ShiWu/MyPython/ModuleLearning/.venv/lib/python3.12/site-packages/langchain_core/language_m │
# │ odels/chat_models.py:799 in generate                                                             │
# │                                                                                                  │
# │    796 │   │   for i, m in enumerate(input_messages):                                            │
# │    797 │   │   │   try:                                                                          │
# │    798 │   │   │   │   results.append(                                                           │
# │ ❱  799 │   │   │   │   │   self._generate_with_cache(                                            │
# │    800 │   │   │   │   │   │   m,                                                                │
# │    801 │   │   │   │   │   │   stop=stop,                                                        │
# │    802 │   │   │   │   │   │   run_manager=run_managers[i] if run_managers else None,            │
# │                                                                                                  │
# │ /home/ShiWu/MyPython/ModuleLearning/.venv/lib/python3.12/site-packages/langchain_core/language_m │
# │ odels/chat_models.py:1045 in _generate_with_cache                                                │
# │                                                                                                  │
# │   1042 │   │   │   │   chunks.append(chunk)                                                      │
# │   1043 │   │   │   result = generate_from_stream(iter(chunks))                                   │
# │   1044 │   │   elif inspect.signature(self._generate).parameters.get("run_manager"):             │
# │ ❱ 1045 │   │   │   result = self._generate(                                                      │
# │   1046 │   │   │   │   messages, stop=stop, run_manager=run_manager, **kwargs                    │
# │   1047 │   │   │   )                                                                             │
# │   1048 │   │   else:                                                                             │
# │                                                                                                  │
# │ /home/ShiWu/MyPython/ModuleLearning/.venv/lib/python3.12/site-packages/langchain_openai/chat_mod │
# │ els/base.py:1131 in _generate                                                                    │
# │                                                                                                  │
# │   1128 │   │   │   response = raw_response.parse()                                               │
# │   1129 │   │   │   generation_info = {"headers": dict(raw_response.headers)}                     │
# │   1130 │   │   else:                                                                             │
# │ ❱ 1131 │   │   │   response = self.client.create(**payload)                                      │
# │   1132 │   │   return self._create_chat_result(response, generation_info)                        │
# │   1133 │                                                                                         │
# │   1134 │   def _use_responses_api(self, payload: dict) -> bool:                                  │
# │                                                                                                  │
# │ /home/ShiWu/MyPython/ModuleLearning/.venv/lib/python3.12/site-packages/openai/_utils/_utils.py:2 │
# │ 87 in wrapper                                                                                    │
# │                                                                                                  │
# │   284 │   │   │   │   │   else:                                                                  │
# │   285 │   │   │   │   │   │   msg = f"Missing required argument: {quote(missing[0])}"            │
# │   286 │   │   │   │   raise TypeError(msg)                                                       │
# │ ❱ 287 │   │   │   return func(*args, **kwargs)                                                   │
# │   288 │   │                                                                                      │
# │   289 │   │   return wrapper  # type: ignore                                                     │
# │   290                                                                                            │
# │                                                                                                  │
# │ /home/ShiWu/MyPython/ModuleLearning/.venv/lib/python3.12/site-packages/openai/resources/chat/com │
# │ pletions/completions.py:1087 in create                                                           │
# │                                                                                                  │
# │   1084 │   │   timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,                     │
# │   1085 │   ) -> ChatCompletion | Stream[ChatCompletionChunk]:                                    │
# │   1086 │   │   validate_response_format(response_format)                                         │
# │ ❱ 1087 │   │   return self._post(                                                                │
# │   1088 │   │   │   "/chat/completions",                                                          │
# │   1089 │   │   │   body=maybe_transform(                                                         │
# │   1090 │   │   │   │   {                                                                         │
# │                                                                                                  │
# │ /home/ShiWu/MyPython/ModuleLearning/.venv/lib/python3.12/site-packages/openai/_base_client.py:12 │
# │ 56 in post                                                                                       │
# │                                                                                                  │
# │   1253 │   │   opts = FinalRequestOptions.construct(                                             │
# │   1254 │   │   │   method="post", url=path, json_data=body, files=to_httpx_files(files), **opti  │
# │   1255 │   │   )                                                                                 │
# │ ❱ 1256 │   │   return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=str  │
# │   1257 │                                                                                         │
# │   1258 │   def patch(                                                                            │
# │   1259 │   │   self,                                                                             │
# │                                                                                                  │
# │ /home/ShiWu/MyPython/ModuleLearning/.venv/lib/python3.12/site-packages/openai/_base_client.py:10 │
# │ 11 in request                                                                                    │
# │                                                                                                  │
# │   1008 │   │   │   │   │   continue                                                              │
# │   1009 │   │   │   │                                                                             │
# │   1010 │   │   │   │   log.debug("Raising connection error")                                     │
# │ ❱ 1011 │   │   │   │   raise APIConnectionError(request=request) from err                        │
# │   1012 │   │   │                                                                                 │
# │   1013 │   │   │   log.debug(                                                                    │
# │   1014 │   │   │   │   'HTTP Response: %s %s "%i %s" %s',                                        │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# APIConnectionError: Connection error.
